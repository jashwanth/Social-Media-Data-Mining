# %% [markdown]
# # CIS600 - Social Media & Data Mining
# ###
# <img src="https://www.syracuse.edu/wp-content/themes/g6-carbon/img/syracuse-university-seal.svg?ver=6.3.9" style="width: 200px;"/>
#
# # Twitter
#
# ###  February 15, 2018

# %%
from twitter import *
import json

# %%
# Loading my authentication tokens
with open('auth_dict.json','r') as f:
    twtr_auth = json.load(f)

# To make it more readable, lets store
# the OAuth credentials in strings first.
CONSUMER_KEY = twtr_auth['consumer_key']
CONSUMER_SECRET = twtr_auth['consumer_secret']
OAUTH_TOKEN = twtr_auth['token']
OAUTH_TOKEN_SECRET = twtr_auth['token_secret']
    
# Then, we store the OAuth object in "auth"
auth = OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
# Notice that there are four tokens - you need to create these in the
# Twitter Apps dashboard after you have created your own "app".

# We now create the twitter search object.
t = Twitter(auth=auth)

# %% [markdown]
# ### We can search trends by geographic region. The Yahoo! Where On Earth ID for the entire world is 1, for example. Look [here](https://developer.twitter.com/en/docs/trends/trends-for-location/api-reference/get-trends-place) for more.

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# ### Let's get the trends (top 50) for the whole world, and then for the US.

# %%
# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = t.trends.place(_id=WORLD_WOE_ID)
us_trends = t.trends.place(_id=US_WOE_ID)

print(world_trends)
print('\n')
print(us_trends)
# Out:
# [{u'created_at': u'2018-02-15T20:10:40Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%86%D8%B5%D8%B1_%D8%A7%D9%84%D8%A8%D8%A7%D8%B7%D9%86', u'query': u'%23%D8%A7%D9%84%D9%86%D8%B5%D8%B1_%D8%A7%D9%84%D8%A8%D8%A7%D8%B7%D9%86', u'tweet_volume': 119787, u'name': u'#\u0627\u0644\u0646\u0635\u0631_\u0627\u0644\u0628\u0627\u0637\u0646', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23GunReformNow', u'query': u'%23GunReformNow', u'tweet_volume': 93662, u'name': u'#GunReformNow', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23%D8%A8%D8%B7%D9%88%D9%84%D9%87_%D8%A7%D9%84%D9%85%D9%85%D9%84%D9%83%D9%87_%D9%84%D9%84%D8%A8%D9%84%D9%88%D8%AA', u'query': u'%23%D8%A8%D8%B7%D9%88%D9%84%D9%87_%D8%A7%D9%84%D9%85%D9%85%D9%84%D9%83%D9%87_%D9%84%D9%84%D8%A8%D9%84%D9%88%D8%AA', u'tweet_volume': 32278, u'name': u'#\u0628\u0637\u0648\u0644\u0647_\u0627\u0644\u0645\u0645\u0644\u0643\u0647_\u0644\u0644\u0628\u0644\u0648\u062a', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23BVBATA', u'query': u'%23BVBATA', u'tweet_volume': 13592, u'name': u'#BVBATA', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23OMSCB', u'query': u'%23OMSCB', u'tweet_volume': 12906, u'name': u'#OMSCB', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Alex+McLeish%22', u'query': u'%22Alex+McLeish%22', u'tweet_volume': None, u'name': u'Alex McLeish', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Manuel+Fernandes%22', u'query': u'%22Manuel+Fernandes%22', u'tweet_volume': None, u'name': u'Manuel Fernandes', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Meninas+Malvadas%22', u'query': u'%22Meninas+Malvadas%22', u'tweet_volume': 26197, u'name': u'Meninas Malvadas', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Afida+Turner%22', u'query': u'%22Afida+Turner%22', u'tweet_volume': None, u'name': u'Afida Turner', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Antonio+Ba%C3%B1os%22', u'query': u'%22Antonio+Ba%C3%B1os%22', u'tweet_volume': None, u'name': u'Antonio Ba\xf1os', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Aduriz', u'query': u'Aduriz', u'tweet_volume': None, u'name': u'Aduriz', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=LimanthaSemCensura', u'query': u'LimanthaSemCensura', u'tweet_volume': 15052, u'name': u'LimanthaSemCensura', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Andrew+Cashner%22', u'query': u'%22Andrew+Cashner%22', u'tweet_volume': None, u'name': u'Andrew Cashner', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Smashing+Pumpkins%22', u'query': u'%22Smashing+Pumpkins%22', u'tweet_volume': None, u'name': u'Smashing Pumpkins', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23EuropaLeague', u'query': u'%23EuropaLeague', u'tweet_volume': 11191, u'name': u'#EuropaLeague', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23%D8%A7%D9%86%D8%BA%D8%A7%D9%85_%D9%81%D8%A8%D8%B1%D8%A7%D9%8A%D8%B1_%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA', u'query': u'%23%D8%A7%D9%86%D8%BA%D8%A7%D9%85_%D9%81%D8%A8%D8%B1%D8%A7%D9%8A%D8%B1_%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA', u'tweet_volume': None, u'name': u'#\u0627\u0646\u063a\u0627\u0645_\u0641\u0628\u0631\u0627\u064a\u0631_\u0627\u0644\u0643\u0648\u064a\u062a', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23BizimMehmedimiz', u'query': u'%23BizimMehmedimiz', u'tweet_volume': 28436, u'name': u'#BizimMehmedimiz', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23CopaACB', u'query': u'%23CopaACB', u'tweet_volume': None, u'name': u'#CopaACB', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23BTSonBillboard', u'query': u'%23BTSonBillboard', u'tweet_volume': 917554, u'name': u'#BTSonBillboard', u'promoted_content': None}, {u'url': u'http://twi ...
#
#
# [{u'created_at': u'2018-02-15T20:10:40Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23GunReformNow', u'query': u'%23GunReformNow', u'tweet_volume': 93662, u'name': u'#GunReformNow', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23WeirdWaysToFlirt', u'query': u'%23WeirdWaysToFlirt', u'tweet_volume': None, u'name': u'#WeirdWaysToFlirt', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23DidntMakeTheOlympicsBecause', u'query': u'%23DidntMakeTheOlympicsBecause', u'tweet_volume': None, u'name': u'#DidntMakeTheOlympicsBecause', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23ThursdayThoughts', u'query': u'%23ThursdayThoughts', u'tweet_volume': 60474, u'name': u'#ThursdayThoughts', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Andrew+Cashner%22', u'query': u'%22Andrew+Cashner%22', u'tweet_volume': None, u'name': u'Andrew Cashner', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23NoMuslimBanEver', u'query': u'%23NoMuslimBanEver', u'tweet_volume': None, u'name': u'#NoMuslimBanEver', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Smashing+Pumpkins%22', u'query': u'%22Smashing+Pumpkins%22', u'tweet_volume': None, u'name': u'Smashing Pumpkins', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Moon+River%22', u'query': u'%22Moon+River%22', u'tweet_volume': 22942, u'name': u'Moon River', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Chris+Bosh%22', u'query': u'%22Chris+Bosh%22', u'tweet_volume': None, u'name': u'Chris Bosh', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Ready+Player+One%22', u'query': u'%22Ready+Player+One%22', u'tweet_volume': None, u'name': u'Ready Player One', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Peter+Thiel%22', u'query': u'%22Peter+Thiel%22', u'tweet_volume': 14019, u'name': u'Peter Thiel', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Neil+LaBute%22', u'query': u'%22Neil+LaBute%22', u'tweet_volume': None, u'name': u'Neil LaBute', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%222019+or+2020+NFL+Draft%22', u'query': u'%222019+or+2020+NFL+Draft%22', u'tweet_volume': None, u'name': u'2019 or 2020 NFL Draft', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22James+Beard%22', u'query': u'%22James+Beard%22', u'tweet_volume': None, u'name': u'James Beard', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Aaron+Feis%22', u'query': u'%22Aaron+Feis%22', u'tweet_volume': 275101, u'name': u'Aaron Feis', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Dortmund', u'query': u'Dortmund', u'tweet_volume': 35991, u'name': u'Dortmund', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Rich+Swann%22', u'query': u'%22Rich+Swann%22', u'tweet_volume': None, u'name': u'Rich Swann', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Happy+Meal%22', u'query': u'%22Happy+Meal%22', u'tweet_volume': None, u'name': u'Happy Meal', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22David+Hogg%22', u'query': u'%22David+Hogg%22', u'tweet_volume': 89494, u'name': u'David Hogg', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Obama-era', u'query': u'Obama-era', u'tweet_volume': 35011, u'name': u'Obama-era', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=Sienna', u'query': u'Sienna', u'tweet_volume': 17250, u'name': u'Sienna', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Lindsey+Graham%22', u'query': u'%22Lindsey+Graham%22', u'tweet_volume': None, u'name': u'Lindsey Graham', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Anthony+Rizzo%22', u'query': u'%22Anthony+Rizzo%22', u'tweet_volume': None, u'name': u'Anthony Rizzo', u'promoted_content': None}, {u'url': u'http://twi ...

# %% [markdown]
# ### That doesn't look so good, so now we "pretty print" it using the JSON module. The builtin *print* gives better output when its input is a JSON object (rather than, say, a string or list object).

# %%
print(json.dumps(world_trends, indent=1))
print('\n')
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "created_at": "2018-02-15T20:10:40Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%86%D8%B5%D8%B1_%D8%A7%D9%84%D8%A8%D8%A7%D8%B7%D9%86",
#     "query": "%23%D8%A7%D9%84%D9%86%D8%B5%D8%B1_%D8%A7%D9%84%D8%A8%D8%A7%D8%B7%D9%86",
#     "tweet_volume": 119787,
#     "name": "#\u0627\u0644\u0646\u0635\u0631_\u0627\u0644\u0628\u0627\u0637\u0646",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GunReformNow",
#     "query": "%23GunReformNow",
#     "tweet_volume": 93662,
#     "name": "#GunReformNow",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A8%D8%B7%D9%88%D9%84%D9%87_%D8%A7%D9%84%D9%85%D9%85%D9%84%D9%83%D9%87_%D9%84%D9%84%D8%A8%D9%84%D9%88%D8%AA",
#     "query": "%23%D8%A8%D8%B7%D9%88%D9%84%D9%87_%D8%A7%D9%84%D9%85%D9%85%D9%84%D9%83%D9%87_%D9%84%D9%84%D8%A8%D9%84%D9%88%D8%AA",
#     "tweet_volume": 32278,
#     "name": "#\u0628\u0637\u0648\u0644\u0647_\u0627\u0644\u0645\u0645\u0644\u0643\u0647_\u0644\u0644\u0628\u0644\u0648\u062a",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BVBATA",
#     "query": "%23BVBATA",
#     "tweet_volume": 13592,
#     "name": "#BVBATA",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OMSCB",
#     "query": "%23OMSCB",
#     "tweet_volume": 12906,
#     "name": "#OMSCB",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Alex+McLeish%22",
#     "query": "%22Alex+McLeish%22",
#     "tweet_volume": null,
#     "name": "Alex McLeish",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Manuel+Fernandes%22",
#     "query": "%22Manuel+Fernandes%22",
#     "tweet_volume": null,
#     "name": "Manuel Fernandes",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Meninas+Malvadas%22",
#     "query": "%22Meninas+Malvadas%22",
#     "tweet_volume": 26197,
#     "name": "Meninas Malvadas",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Afida+Turner%22",
#     "query": "%22Afida+Turner%22",
#     "tweet_volume": null,
#     "name": "Afida Turner",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Antonio+Ba%C3%B1os%22",
#     "query": "%22Antonio+Ba%C3%B1os%22",
#     "tweet_volume": null,
#     "name": "Antonio Ba\u00f1os",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Aduriz",
#     "query": "Aduriz",
#     "tweet_volume": null,
#     "name": "Aduriz",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=LimanthaSemCensura",
#     "query": "LimanthaSemCensura",
#     "tweet_volume": 15052,
#     "name": "LimanthaSemCensura",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Andrew+Cashner%22",
#     "query": "%22Andrew+Cashner%22",
#     "tweet_volume": null,
#     "name": "Andrew Cashner",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Smashing+Pumpkins%22",
#     "query": "%22Smashing+Pumpkins%22",
#     "tweet_volume": null,
#     "name": "Smashing Pumpkins",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EuropaLeague",
#     "query": "%23EuropaLeague",
#     "tweet_volume": 11191,
#     "name": "#EuropaLeague",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%86%D8%BA%D8%A7%D9%85_%D9%81%D8%A8%D8%B1%D8%A7%D9%8A%D8%B1_%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA",
#     "query": "%23%D8%A7%D9%86%D8%BA%D8%A7%D9%85_%D9%81%D8%A8%D8%B1%D8%A7%D9%8A%D8%B1_%D8%A7%D9%84%D9%83%D9%88%D9%8A%D8%AA",
#     "tweet_volume": null,
#     "name": "#\u0627\u0646\u063a\u0627\u0645_\u0641\u0628\u0631\u0627\u064a\u0631_\u0627\u0644\u0643\u0648\u064a\u062a",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BizimMehmedimiz",
#     "query": "%23BizimMehmedimiz",
#     "tweet_volume": 28436,
#     "name": "#BizimMehmedimiz",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CopaACB",
#     "query": "%23CopaACB",
#     "tweet_volume": null,
#     "name": "#CopaACB",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BTSonBillboard",
#     "query": "%23BTSonBillboard",
#     "tweet_volume": 917554,
#     "name": "#BTSonBillboard",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23D%C3%ADaDeLaMujerMexicana",
#     "query": "%23D%C3%ADaDeLaMujerMexicana",
#     "tweet_volume": null,
#     "name": "#D\u00edaDeLaMujerMexicana",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LudogoretsMilan",
#     "query": "%23LudogoretsMilan",
#     "tweet_volume": null,
#     "name": "#LudogoretsMilan",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%AD%D9%8A%D8%A7%D8%AA%D9%8312",
#     "query": "%23%D8%AD%D9%8A%D8%A7%D8%AA%D9%8312",
#     "tweet_volume": 31964,
#     "name": "#\u062d\u064a\u0627\u062a\u064312",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OSTvAFC",
#     "query": "%23OSTvAFC",
#     "tweet_volume": 17734,
#     "name": "#OSTvAFC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FabioOMelhorDoBrasil",
#     "query": "%23FabioOMelhorDoBrasil",
#     "tweet_volume": 18132,
#     "name": "#FabioOMelhorDoBrasil",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%2315Feb",
#     "query": "%2315Feb",
#     "tweet_volume": 57552,
#     "name": "#15Feb",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WeirdWaysToFlirt",
#     "query": "%23WeirdWaysToFlirt",
#     "tweet_volume": null,
#     "name": "#WeirdWaysToFlirt",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%B9%D9%84%D8%A7%D9%86_%D8%AA%D8%AD%D9%82%D9%8A%D9%82%D8%A7%D8%AA_%D8%A7%D9%84%D8%A7%D8%AA%D8%AD%D8%A7%D8%AF",
#     "query": "%23%D8%A7%D8%B9%D9%84%D8%A7%D9%86_%D8%AA%D8%AD%D9%82%D9%8A%D9%82%D8%A7%D8%AA_%D8%A7%D9%84%D8%A7%D8%AA%D8%AD%D8%A7%D8%AF",
#     "tweet_volume": null,
#     "name": "#\u0627\u0639\u0644\u0627\u0646_\u062a\u062d\u0642\u064a\u0642\u0627\u062a_\u0627\u0644\u0627\u062a\u062d\u0627\u062f",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23cinerimborsi",
#     "query": "%23cinerimborsi",
#     "tweet_volume": null,
#     "name": "#cinerimborsi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TellMeYouLoveMeTour",
#     "query": "%23TellMeYouLoveMeTour",
#     "tweet_volume": 36973,
#     "name": "#TellMeYouLoveMeTour",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DidntMakeTheOlympicsBecause",
#     "query": "%23DidntMakeTheOlympicsBecause",
#     "tweet_volume": null,
#     "name": "#DidntMakeTheOlympicsBecause",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%87%D9%84_%D8%A7%D9%86%D8%AA_%D9%85%D8%AF%D9%85%D9%86_%D8%A7%D9%86%D8%AA%D8%B1_%D9%86%D8%AA_%D8%A7%D9%88_%D9%84%D8%A7",
#     "query": "%23%D9%87%D9%84_%D8%A7%D9%86%D8%AA_%D9%85%D8%AF%D9%85%D9%86_%D8%A7%D9%86%D8%AA%D8%B1_%D9%86%D8%AA_%D8%A7%D9%88_%D9%84%D8%A7",
#     "tweet_volume": 21250,
#     "name": "#\u0647\u0644_\u0627\u0646\u062a_\u0645\u062f\u0645\u0646_\u0627\u0646\u062a\u0631_\u0646\u062a_\u0627\u0648_\u0644\u0627",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23KaregolBet10TLHediyee",
#     "query": "%23KaregolBet10TLHediyee",
#     "tweet_volume": null,
#     "name": "#KaregolBet10TLHediyee",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FW41",
#     "query": "%23FW41",
#     "tweet_volume": null,
#     "name": "#FW41",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SalarioRosa",
#     "query": "%23SalarioRosa",
#     "tweet_volume": null,
#     "name": "#SalarioRosa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TheRoomParis",
#     "query": "%23TheRoomParis",
#     "tweet_volume": null,
#     "name": "#TheRoomParis",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ateema",
#     "query": "%23ateema",
#     "tweet_volume": null,
#     "name": "#ateema",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23referendumdebat",
#     "query": "%23referendumdebat",
#     "tweet_volume": null,
#     "name": "#referendumdebat",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23goedgeldgala",
#     "query": "%23goedgeldgala",
#     "tweet_volume": null,
#     "name": "#goedgeldgala",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OLVIL",
#     "query": "%23OLVIL",
#     "tweet_volume": null,
#     "name": "#OLVIL",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ThoughtContagion",
#     "query": "%23ThoughtContagion",
#     "tweet_volume": null,
#     "name": "#ThoughtContagion",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SPORSORA18",
#     "query": "%23SPORSORA18",
#     "tweet_volume": null,
#     "name": "#SPORSORA18",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23S%C3%BCresizNafakaHakm%C4%B1d%C4%B1r",
#     "query": "%23S%C3%BCresizNafakaHakm%C4%B1d%C4%B1r",
#     "tweet_volume": 13968,
#     "name": "#S\u00fcresizNafakaHakm\u0131d\u0131r",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EnElTrabajoEsNormal",
#     "query": "%23EnElTrabajoEsNormal",
#     "tweet_volume": null,
#     "name": "#EnElTrabajoEsNormal",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Hesapla%C5%9FmaVakti",
#     "query": "%23Hesapla%C5%9FmaVakti",
#     "tweet_volume": null,
#     "name": "#Hesapla\u015fmaVakti",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23UnEstudioComprob%C3%B3Que",
#     "query": "%23UnEstudioComprob%C3%B3Que",
#     "tweet_volume": null,
#     "name": "#UnEstudioComprob\u00f3Que",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23VenACenar109",
#     "query": "%23VenACenar109",
#     "tweet_volume": null,
#     "name": "#VenACenar109",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23StilBahisY%C3%BCksekKazan%C3%A7lar",
#     "query": "%23StilBahisY%C3%BCksekKazan%C3%A7lar",
#     "tweet_volume": null,
#     "name": "#StilBahisY\u00fcksekKazan\u00e7lar",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CobraKai",
#     "query": "%23CobraKai",
#     "tweet_volume": null,
#     "name": "#CobraKai",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%2325propositionsFH",
#     "query": "%2325propositionsFH",
#     "tweet_volume": null,
#     "name": "#25propositionsFH",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LEmissionPolitique",
#     "query": "%23LEmissionPolitique",
#     "tweet_volume": null,
#     "name": "#LEmissionPolitique",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2018-02-15T20:15:06Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
#
# [
#  {
#   "created_at": "2018-02-15T20:10:40Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23GunReformNow",
#     "query": "%23GunReformNow",
#     "tweet_volume": 93662,
#     "name": "#GunReformNow",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WeirdWaysToFlirt",
#     "query": "%23WeirdWaysToFlirt",
#     "tweet_volume": null,
#     "name": "#WeirdWaysToFlirt",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DidntMakeTheOlympicsBecause",
#     "query": "%23DidntMakeTheOlympicsBecause",
#     "tweet_volume": null,
#     "name": "#DidntMakeTheOlympicsBecause",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ThursdayThoughts",
#     "query": "%23ThursdayThoughts",
#     "tweet_volume": 60474,
#     "name": "#ThursdayThoughts",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Andrew+Cashner%22",
#     "query": "%22Andrew+Cashner%22",
#     "tweet_volume": null,
#     "name": "Andrew Cashner",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NoMuslimBanEver",
#     "query": "%23NoMuslimBanEver",
#     "tweet_volume": null,
#     "name": "#NoMuslimBanEver",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Smashing+Pumpkins%22",
#     "query": "%22Smashing+Pumpkins%22",
#     "tweet_volume": null,
#     "name": "Smashing Pumpkins",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Moon+River%22",
#     "query": "%22Moon+River%22",
#     "tweet_volume": 22942,
#     "name": "Moon River",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Chris+Bosh%22",
#     "query": "%22Chris+Bosh%22",
#     "tweet_volume": null,
#     "name": "Chris Bosh",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ready+Player+One%22",
#     "query": "%22Ready+Player+One%22",
#     "tweet_volume": null,
#     "name": "Ready Player One",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Peter+Thiel%22",
#     "query": "%22Peter+Thiel%22",
#     "tweet_volume": 14019,
#     "name": "Peter Thiel",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Neil+LaBute%22",
#     "query": "%22Neil+LaBute%22",
#     "tweet_volume": null,
#     "name": "Neil LaBute",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%222019+or+2020+NFL+Draft%22",
#     "query": "%222019+or+2020+NFL+Draft%22",
#     "tweet_volume": null,
#     "name": "2019 or 2020 NFL Draft",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22James+Beard%22",
#     "query": "%22James+Beard%22",
#     "tweet_volume": null,
#     "name": "James Beard",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Aaron+Feis%22",
#     "query": "%22Aaron+Feis%22",
#     "tweet_volume": 275101,
#     "name": "Aaron Feis",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Dortmund",
#     "query": "Dortmund",
#     "tweet_volume": 35991,
#     "name": "Dortmund",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Rich+Swann%22",
#     "query": "%22Rich+Swann%22",
#     "tweet_volume": null,
#     "name": "Rich Swann",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Happy+Meal%22",
#     "query": "%22Happy+Meal%22",
#     "tweet_volume": null,
#     "name": "Happy Meal",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22David+Hogg%22",
#     "query": "%22David+Hogg%22",
#     "tweet_volume": 89494,
#     "name": "David Hogg",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Obama-era",
#     "query": "Obama-era",
#     "tweet_volume": 35011,
#     "name": "Obama-era",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Sienna",
#     "query": "Sienna",
#     "tweet_volume": 17250,
#     "name": "Sienna",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Lindsey+Graham%22",
#     "query": "%22Lindsey+Graham%22",
#     "tweet_volume": null,
#     "name": "Lindsey Graham",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Anthony+Rizzo%22",
#     "query": "%22Anthony+Rizzo%22",
#     "tweet_volume": null,
#     "name": "Anthony Rizzo",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Reggie+Lynch%22",
#     "query": "%22Reggie+Lynch%22",
#     "tweet_volume": null,
#     "name": "Reggie Lynch",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Loch+Raven+High+School%22",
#     "query": "%22Loch+Raven+High+School%22",
#     "tweet_volume": null,
#     "name": "Loch Raven High School",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Ciara",
#     "query": "Ciara",
#     "tweet_volume": 23112,
#     "name": "Ciara",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Everything%22",
#     "query": "%22Everything%22",
#     "tweet_volume": 873026,
#     "name": "\"Everything\"",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Nacho+Monreal%22",
#     "query": "%22Nacho+Monreal%22",
#     "tweet_volume": null,
#     "name": "Nacho Monreal",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Austin-based",
#     "query": "Austin-based",
#     "tweet_volume": null,
#     "name": "Austin-based",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Welbeck",
#     "query": "Welbeck",
#     "tweet_volume": null,
#     "name": "Welbeck",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CobraKai",
#     "query": "%23CobraKai",
#     "tweet_volume": null,
#     "name": "#CobraKai",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ewaCHARACTER",
#     "query": "%23ewaCHARACTER",
#     "tweet_volume": null,
#     "name": "#ewaCHARACTER",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ThoughtContagion",
#     "query": "%23ThoughtContagion",
#     "tweet_volume": null,
#     "name": "#ThoughtContagion",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CultureTrav",
#     "query": "%23CultureTrav",
#     "tweet_volume": null,
#     "name": "#CultureTrav",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EuropaLeague",
#     "query": "%23EuropaLeague",
#     "tweet_volume": 11191,
#     "name": "#EuropaLeague",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Engage4Health",
#     "query": "%23Engage4Health",
#     "tweet_volume": null,
#     "name": "#Engage4Health",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HISDSOTS",
#     "query": "%23HISDSOTS",
#     "tweet_volume": null,
#     "name": "#HISDSOTS",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23zohoday",
#     "query": "%23zohoday",
#     "tweet_volume": null,
#     "name": "#zohoday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NCE18",
#     "query": "%23NCE18",
#     "tweet_volume": null,
#     "name": "#NCE18",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AAASmtg",
#     "query": "%23AAASmtg",
#     "tweet_volume": null,
#     "name": "#AAASmtg",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23KungFury",
#     "query": "%23KungFury",
#     "tweet_volume": null,
#     "name": "#KungFury",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23100BestCos",
#     "query": "%23100BestCos",
#     "tweet_volume": null,
#     "name": "#100BestCos",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GatorDay",
#     "query": "%23GatorDay",
#     "tweet_volume": null,
#     "name": "#GatorDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AmySchumer",
#     "query": "%23AmySchumer",
#     "tweet_volume": null,
#     "name": "#AmySchumer",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BTSonBillboard",
#     "query": "%23BTSonBillboard",
#     "tweet_volume": 917554,
#     "name": "#BTSonBillboard",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23morethanababe",
#     "query": "%23morethanababe",
#     "tweet_volume": null,
#     "name": "#morethanababe",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TravelHappy",
#     "query": "%23TravelHappy",
#     "tweet_volume": null,
#     "name": "#TravelHappy",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TwitterSmarter",
#     "query": "%23TwitterSmarter",
#     "tweet_volume": null,
#     "name": "#TwitterSmarter",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AnthroDay",
#     "query": "%23AnthroDay",
#     "tweet_volume": null,
#     "name": "#AnthroDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OSTvAFC",
#     "query": "%23OSTvAFC",
#     "tweet_volume": 17734,
#     "name": "#OSTvAFC",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2018-02-15T20:15:06Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %% [markdown]
# ### Now that we have both results in memory, we can combine them. For example, we find the intersection of the top world trends and the top USA trends.

# %%
# Why bother with "set" here?
world_trends_set = set([trend['name'] for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)

# %% [markdown]
# ### Next, let's collect search results in a loop. Note that we are already able to do this with the Search API and that the Streaming API will be needed for larger volume.

# %% [markdown]
# ### The *count* parameter below is the same parameter we saw before and represents the number of tweets we want *per page*. This was stated incorrectly in Tuesday's lecture and notebook.

# %% [markdown]
# ### This is important because the Twitter REST API uses *cursoring* to organize large search results in *pages*. The next example shows how to use the cursor. Read more about it [here](https://developer.twitter.com/en/docs/basics/cursoring)

# %%
# Set the next variable to any trending topic
# or anything else for that matter.
q = '"Super Bowl"' 

# Same as before - the number of tweets we want *per page*.
count = 1000

# We do the search call.
search_results = t.search.tweets(q=q, count=count)

# Remember 'status' refers to the actual content of a tweet.
# (as opposed to the metadata)
statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor.
# The use of the underscore "_" below is a convention in python 
# indicating to the reader that the variable will not be used for
# anything within the loop.
for _ in range(5):
    print("Length of statuses ", len(statuses))
    # Remember "try...except"? Here it is in action:
    try:
        next_results = search_results['search_metadata']['next_results']
    # No more results when next_results doesn't exist
    except KeyError as e: 
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = t.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# ('Length of statuses ', 100)
# ('Length of statuses ', 200)
# ('Length of statuses ', 200)
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "@NFLonFOX He already has one and a Super Bowl MVP good job guys",
#  "is_quote_status": false,
#  "in_reply_to_status_id": 964227415944785920,
#  "id": 964231634370392064,
#  "favorite_count": 1,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 23508439,
#     "indices": [
#      0,
#      9
#     ],
#     "id_str": "23508439",
#     "screen_name": "NFLonFOX",
#     "name": "FOX Sports: NFL"
#    }
#   ],
#   "hashtags": [],
#   "urls": []
#  },
#  "retweeted": false,
#  "coordinates": null,
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_screen_name": "NFLonFOX",
#  "in_reply_to_user_id": 23508439,
#  "retweet_count": 0,
#  "id_str": "964231634370392064",
#  "favorited": false,
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "default_profile_image": true,
#   "id": 896937497154007040,
#   "profile_background_image_url_https": null,
#   "verified": false,
#   "translator_type": "none",
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 8,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "896937497154007040",
#   "profile_background_color": "F5F8FA",
#   "listed_count": 0,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 28,
#   "description": "",
#   "friends_count": 504,
#   "location": "",
#   "profile_link_color": "1DA1F2",
#   "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "following": false,
#   "geo_enabled": false,
#   "profile_background_image_url": null,
#   "screen_name": "DylanBuz19",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 43,
#   "name": "Dylan Busby",
#   "notifications": false,
#   "url": null,
#   "created_at": "Mon Aug 14 03:32:18 +0000 2017",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": "23508439",
#  "lang": "en",
#  "created_at": "Thu Feb 15 20:15:10 +0000 2018",
#  "in_reply_to_status_id_str": "964227415944785920",
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %% [markdown]
# ### Note the "except" line in the cell above. Including "as e" after the "KeyError" lets you access the attributes of the error - we didn't do that, but you might find a need for it. Inside the indent, you could manipulate the object e and get its attributes, such as e.args.
#
# ### Instead, we simply break out of the loop.

# %% [markdown]
# ### In the next example, we extract text, screen names and hashtags from tweets.

# %%
status_texts = [ status['text'] for status in statuses ]

screen_names = [ user_mention['screen_name'] for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w for t in status_texts for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "@NFLonFOX He already has one and a Super Bowl MVP good job guys",
#  "RT @ajmaestas: Congrats to my great friend Ryan Peck and his growing business @TranSportsGroup on a trailblazing weekend at Super Bowl! So\u2026",
#  "Touchdown! Please Like/Share. Thanks!  #Solo #StarWars #JurassicWorld2 #MissionImpos... https://t.co/EojDy8VVvX",
#  "RT @Smitty09TPS: Thanks @TheUBB and Bry for the Super Bowl bonus box. Sure, I\u2019ll take 4 Extra hits (3 of them /10) from @PaniniAmerica Nati\u2026",
#  "RT @chitchatwithcat: My latest column: Ertz's Super Bowl win has town, family ecstatic https://t.co/3049pLWqAL via @eastbaytimes"
# ]
# [
#  "NFLonFOX",
#  "ajmaestas",
#  "TranSportsGroup",
#  "Smitty09TPS",
#  "TheUBB"
# ]
# [
#  "Solo",
#  "StarWars",
#  "JurassicWorld2",
#  "MissionImpos",
#  "XOXOTeam"
# ]
# [
#  "@NFLonFOX",
#  "He",
#  "already",
#  "has",
#  "one"
# ]

# %% [markdown]
# ### We can create a basic frequency distribution from words in tweets. A first glimpse at NLP!

# %%
from collections import Counter

# Recall that you can loop through any
# iterator in python - such as a list
# of lists!
for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [(u'the', 142), (u'Super', 124), (u'RT', 116), (u'Bowl', 99), (u'a', 60), (u'to', 56), (u'and', 47), (u'of', 36), (u'for', 34), (u'with', 33)]
# [(u'NFLonFOX', 14), (u'musiquefeed', 12), (u'EXOVotingSquad', 6), (u'Saints', 6), (u'WhoDat_Joness', 5), (u'bchartsnet', 4), (u'PaulKuharskyNFL', 3), (u'FanRagSports', 3), (u'forumpandlr', 2), (u'TheUBB', 2)]
# [(u'EXOL', 8), (u'SuperBowl', 7), (u'iHeartAwards', 7), (u'BestFanArmy', 7), (u'XOXOTeam', 5), (u'Vikings', 3), (u'FlyEaglesFly', 3), (u'PrinceWins', 3), (u'Titans', 3), (u'Texans', 3)]

# %% [markdown]
# ### Going a little further, we can calculate the *lexical diversity* of our tweets.

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.395285830398
# 0.666666666667
# 0.45652173913
# 18

# %% [markdown]
# ### Question: why didn't we multiply by "1.0" in the return value of "average_words"?

# %% [markdown]
# ### We can plot the frequencies of words using matplotlib.

# %%
import matplotlib.pyplot as plt

# First, we get the frequencies in order.
word_counts = sorted(Counter(words).values(), reverse=True)

# We can plot it along log-scaled axes
plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5,0,'Word Rank')

# %% [markdown]
# ### And now we "show" it.

# %%
plt.show()

# %% [markdown]
# ### We can also do histograms.

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.show()

# %% [markdown]
# ### And now for something completely different...finding the most popular retweets

# %%
retweets = [
            # We are building a list of tuples
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'],
             status['retweeted_status']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %%
retweets

# %% [markdown]
# ### Rmk: In Python2, dictionaries have a "has_key" method. This was dropped from Python3

# %% [markdown]
# ### Looking up users who have retweeted a 'status'.

# %% [markdown]
# ### First, let's pick one of the retweets. We will find the id of the original tweet from the 'retweeted_status' node (the last element of our tuple).

# %%
retweets[0][-1]['id']
# Out:
# 963844963975954432

# %% [markdown]
# ### This is the id of the retweeted tweet. We will use this to search Twitter again.

# %%
# Note that we are doing another search here.
_retweets = t.statuses.retweets(id=963844963975954432)
print([r['user']['screen_name'] for r in _retweets])

# %% [markdown]
# ### Finally, let's look at a histogram of retweet counts

# %%
counts = [count for count, _, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print(counts)
plt.show()

# %% [markdown]
# # Twitter Functions

# %% [markdown]
# ### We want to reuse the code from the cells above. Also, we want to write clean and readable code when we implement longer and more complex procedures. So let's

# %%
def oauth_login():
    # Replace credentials below with appropriate values - 
    # this works in the TwitterAPIcontd notebook because
    # we defined the credentials above
    CONSUMER_KEY = CONSUMER_KEY
    CONSUMER_SECRET = CONSUMER_SECRET
    OAUTH_TOKEN = OAUTH_TOKEN
    OAUTH_TOKEN_SECRET = OAUTH_TOKEN_SECRET
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
    CONSUMER_KEY, CONSUMER_SECRET)
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

# %% [markdown]
# ### Next, we can wrap the lines that give us trends in a function.

# %%
def twitter_trends(twitter_api, woe_id):
    # Prefix ID with the underscore for query string parameterization.
    # Without the underscore, the twitter package appends the ID value
    # to the URL itself as a special-case keyword argument.
    return twitter_api.trends.place(_id=woe_id)

# %% [markdown]
# ### Likewise, we define a function for the looped twitter search.

# %%
def twitter_search(twitter_api, q, max_results=200, **kw):
    search_results = twitter_api.search.tweets(q=q, count=100, **kw)
    statuses = search_results['statuses']
    # Enforce a reasonable limit
    max_results = min(1000, max_results)
    for _ in range(10): # 10*100 = 1000
        try:
            next_results = search_results['search_metadata']['next_results']
        except KeyError as e: # No more results when next_results doesn't exist
            break
        # Create a dictionary from next_results, which has the following form:
        # ?max_id=313519052523986943&q=NCAA&include_entities=1
        kwargs = dict([ kv.split('=') 
                       for kv in next_results[1:].split("&") ])
        search_results = twitter_api.search.tweets(**kwargs)
        statuses += search_results['statuses']
        if len(statuses) > max_results:
            break
    
    return statuses

# %% [markdown]
# ### You will likely encounter errors in mining Twitter data. Here is a function to automate the handling of certain errors. See *Mining the Social Web* for more details.

# %%
import sys
import time
from twitter.api import TwitterHTTPError
from urllib.error import URLError
from http.client import BadStatusLine

def make_twitter_request(twitter_api_func, max_errors=10, *args, **kw):
    # A nested helper function that handles common HTTPErrors. Return an updated
    # value for wait_period if the problem is a 500 level error. Block until the
    # rate limit is reset if it's a rate limiting issue (429 error). Returns None
    # for 401 and 404 errors, which requires special handling by the caller.
    def handle_twitter_http_error(e, wait_period=2, sleep_when_rate_limited=True):
        if wait_period > 3600: # Seconds
            print('Too many retries. Quitting.', file=sys.stderr)
            raise e
        if e.e.code == 401:
            return None
        elif e.e.code == 404:
            print('Encountered 404 Error (Not Found)', file=sys.stderr)
            return None
        elif e.e.code == 429:
            print('Encountered 429 Error (Rate Limit Exceeded)', file=sys.stderr)
            if sleep_when_rate_limited:
                print("Retrying in 15 minutes...ZzZ...", file=sys.stderr)
                sys.stderr.flush()
                time.sleep(60*15 + 5)
                print('...ZzZ...Awake now and trying again.', file=sys.stderr)
                return 2
            else:
                raise e # Caller must handle the rate limiting issue
        elif e.e.code in (500, 502, 503, 504):
            print('Encountered %i Error. Retrying in %i seconds' % (e.e.code, wait_period), file=sys.stderr)
            time.sleep(wait_period)
            wait_period *= 1.5
            return wait_period
        else:
            raise e

    # End of nested helper function

    wait_period = 2
    error_count = 0
    while True:
        try:
            return twitter_api_func(*args, **kw)
        except TwitterHTTPError as e:
            error_count = 0
            wait_period = handle_twitter_http_error(e, wait_period)
            if wait_period is None:
                return
        except URLError as e:
            error_count += 1
            print("URLError encountered. Continuing.", file=sys.stderr)
            if error_count > max_errors:
                print("Too many consecutive errors...bailing out.", file=sys.stderr)
                raise
        except BadStatusLine as e:
            error_count += 1
            print >> sys.stderr, "BadStatusLine encountered. Continuing."
            if error_count > max_errors:
                print("Too many consecutive errors...bailing out.", file=sys.stderr)
                raise

# %%
response = make_twitter_request(t.users.lookup, screen_name="SocialWebMining")

# %%
response

# %% [markdown]
# # Streaming Revisited

# %% [markdown]
# ### We will want to write responses to disk, on the fly, so that we can collect many observations for later analysis. In *Mining the Social Web*, the Mongo DB database program is recommended. Here is another way (that also can be adapted so that it writes to a database).

# %% [markdown]
# ### First, let's wrap the extraction of tweet "[entities](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/entities-object)" in a function which takes a list of statuses as input.

# %%
def extract_tweet_entities(statuses):
    if len(statuses) == 0:
        return [], [], [], [], []
    screen_names = [ user_mention['screen_name'] 
                    for status in statuses
                        for user_mention in status['entities']['user_mentions'] ]
    hashtags = [ hashtag['text']
                    for status in statuses
                        for hashtag in status['entities']['hashtags'] ]
    urls = [ url['expanded_url']
                    for status in statuses
                        for url in status['entities']['urls'] ]
    symbols = [ symbol['text']
                    for status in statuses
                        for symbol in status['entities']['symbols'] ]
    if status['entities'].has_key('media'):
        media = [ media['url']
            for status in statuses
                for media in status['entities']['media'] ]
    else:
        media = []
    return screen_names, hashtags, urls, media, symbols

# %% [markdown]
# ### The above function is a good template of sorts. You can use it to develop your own function for extracting other information from a *list of statuses*.

# %% [markdown]
# ### Let's define two more functions, then we'll sample from the "Twitter Firehose", writing results as we go. The functions below will take statuses, extract some information, and then write the results into a CSV file using Pandas.

# %%
def extract_tweet_basics(status):
    screen_name = None
    tweet_ID = None
    text = None
    if 'user' in status:
        screen_name = status['user']['screen_name'] 
        tweet_ID = status['id']
        text = status['text']
    return screen_name, tweet_ID, text

# %%
def tweet_to_csv(file, status):
    screen_name, tweet_ID, text = extract_tweet_basics(status)
    df = pd.DataFrame([[screen_name,tweet_ID,text]], columns=['screen_name','tweet_ID','text'])
    with open(file, 'a') as f:
        df.to_csv(f,header=False, index=False)

# %% [markdown]
# ### Finally, we stick this in the streaming loop from last time.

# %%
# Create a *streaming* connection (not RESTful, different from Search).
t_stream = TwitterStream(auth=auth)


# Get an *iterator* object from the twitter wrapper

tweeterator = t_stream.statuses.sample()

# Create a CSV file with column names
# but no data (yet).
import pandas as pd
df = pd.DataFrame(columns=['screen_name','tweet_ID','text'])
df.to_csv('my_csv.csv', index=False)


# The loop below will grab a new tweet,
# extract some basic info, put that info
# in a dataframe object, then use that
# dataframe object to append one row to
# the existing CSV file, 'my_csv.csv'.

tweet_count = 10
for tweet in tweeterator:
    tweet_count -= 1
    tweet_to_csv('my_csv.csv', tweet)  
    if tweet_count <= 0:
        break

# %% [markdown]
# ### Rmk: Pandas has a *lot* going on. For example, it makes connecting to a SQL database very easy. Recording results to a database using Pandas is almost as easy as writing to a file.
